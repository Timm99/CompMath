# %%
import numpy as np
import math

import matplotlib.pyplot as plt

# %%
x_data = np.arange(1910,2001,10)
y_data = np.array([92228496, 106021537, 123202624, 132164569, 151325798, 179323175, 203211926, 226545805, 248709873, 281421906])
N = np.size(x_data)

# %%
#Пункт 1

# %%
B = np.polynomial.polynomial.polyval(x_data,np.eye(5))
A = B@B.transpose()
F = B@y_data

# %%
c_1 = np.linalg.solve(A,F)
x_plot = np.arange(1910,2001,0.1)
y_plot = np.polynomial.polynomial.polyval(x_plot,c_1)
#Предсказание 
Predict_A_5 = np.polynomial.polynomial.polyval(2010,c_1)
print(Predict_A_5)
# Out:
# 304914466.0390625

# %%
fig = plt.figure()
plt.plot(x_data,y_data,"o")
plt.plot(x_plot,y_plot)
plt.show()

# %%
#Пункт В

# %%
z_data = x_data - 1955

# %%
B = np.polynomial.polynomial.polyval(z_data,np.eye(5))
A = B@B.transpose()
F = B@y_data

# %%
c_2 = np.linalg.solve(A,F)
z_plot = np.arange(-45,45,0.1)
yz_plot = np.polynomial.polynomial.polyval(z_plot,c_2)
#Предсказание 
Predict_C_5 = np.polynomial.polynomial.polyval(55,c_2)
print(Predict_C_5)
# Out:
# 305706175.5000001

# %%
fig_2 = plt.figure()
plt.plot(x_data,y_data,"o")
plt.plot(z_plot+1955,yz_plot)
plt.show()
